# %%
# %pip install "giskard[llm]>=2.0.0b" --upgrade
# Out:
# Collecting giskard[llm]>=2.0.0b
#   Obtaining dependency information for giskard[llm]>=2.0.0b from https://files.pythonhosted.org/packages/64/d8/388e4b720f54418e86255c14dc41e1df19461764b35984c3c017b49d54c9/giskard-2.0.2-py3-none-any.whl.metadata
#   Downloading giskard-2.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=1.1.1 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for cloudpickle>=1.1.1 from https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting zstandard>=0.10.0 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for zstandard>=0.10.0 from https://files.pythonhosted.org/packages/54/fc/c1b1a1e140451f3362789f546731b3ef36c78668be19d7fc6fbd4326b535/zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.9 kB)
# Collecting mlflow-skinny>=2 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for mlflow-skinny>=2 from https://files.pythonhosted.org/packages/ee/5c/4d3c0bc4cef084bd5e776d14ff028f23af1ac967338bb0b82e2c24e1e006/mlflow_skinny-2.8.0-py3-none-any.whl.metadata
#   Downloading mlflow_skinny-2.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting protobuf<3.21 (from giskard[llm]>=2.0.0b)
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 913.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.22.0 in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (1.26.1)
# Collecting scikit-learn>=1.0 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for scikit-learn>=1.0 from https://files.pythonhosted.org/packages/40/c6/2e91eefb757822e70d351e02cc38d07c137212ae7c41ac12746415b4860a/scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Using cached scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting scipy>=1.7.3 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for scipy>=1.7.3 from https://files.pythonhosted.org/packages/50/8b/2057417a07a6fee8ed8be40e37bac4a502cae4cf44468a02962bbe81b8af/scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Using cached scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl.metadata (165 kB)
# Collecting mixpanel>=4.4.0 (from giskard[llm]>=2.0.0b)
#   Downloading mixpanel-4.10.0-py2.py3-none-any.whl (8.9 kB)
# Requirement already satisfied: requests>=2.19 in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (2.31.0)
# Collecting pydantic<3,>1 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pydantic<3,>1 from https://files.pythonhosted.org/packages/73/66/0a72c9fcde42e5650c8d8d5c5c1873b9a3893018020c77ca8eb62708b923/pydantic-2.4.2-py3-none-any.whl.metadata
#   Using cached pydantic-2.4.2-py3-none-any.whl.metadata (158 kB)
# Collecting pandas>=1.3.4 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pandas>=1.3.4 from https://files.pythonhosted.org/packages/4e/dd/4a77fb4cb7d207fbeb77dfc7c022131d295767504eabb5836fcd63b644a1/pandas-2.1.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached pandas-2.1.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting xxhash>=3.2.0 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for xxhash>=3.2.0 from https://files.pythonhosted.org/packages/9c/0a/d0fd8d78c8a2c3c3b34e7a9dccf85f01bf38f32e0228d107fa3903e0981f/xxhash-3.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading xxhash-3.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting langdetect>=1.0.9 (from giskard[llm]>=2.0.0b)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 803.5 kB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting chardet (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: jinja2>=3 in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (3.1.2)
# Collecting requests-toolbelt>=0.9.1 (from giskard[llm]>=2.0.0b)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting stomp-py>=8.1.0 (from giskard[llm]>=2.0.0b)
#   Downloading stomp.py-8.1.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (65.5.0)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (4.8.0)
# Requirement already satisfied: websocket-client in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (1.6.4)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (6.0.1)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from giskard[llm]>=2.0.0b) (23.2)
# Collecting markdown (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for markdown from https://files.pythonhosted.org/packages/70/58/2c5a654173937d9f540a4971c569b44dcd55e5424a484d954cdaeebcf79c/Markdown-3.5.1-py3-none-any.whl.metadata
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting colorama (from giskard[llm]>=2.0.0b)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting langchain<=0.0.301 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for langchain<=0.0.301 from https://files.pythonhosted.org/packages/fa/7c/2165c25b08cce00d7271c03f4f35897a86853040fb2d1d99ef0182f9b164/langchain-0.0.301-py3-none-any.whl.metadata
#   Downloading langchain-0.0.301-py3-none-any.whl.metadata (15 kB)
# Collecting openai<=0.28.1 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for openai<=0.28.1 from https://files.pythonhosted.org/packages/1e/9f/385c25502f437686e4aa715969e5eaf5c2cb5e5ffa7c5cdd52f3c6ae967a/openai-0.28.1-py3-none-any.whl.metadata
#   Using cached openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# Collecting evaluate>=0.4.1 (from giskard[llm]>=2.0.0b)
#   Obtaining dependency information for evaluate>=0.4.1 from https://files.pythonhosted.org/packages/70/63/7644a1eb7b0297e585a6adec98ed9e575309bb973c33b394dae66bc35c69/evaluate-0.4.1-py3-none-any.whl.metadata
#   Downloading evaluate-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting bert-score>=0.3.13 (from giskard[llm]>=2.0.0b)
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 616.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: torch>=1.0.0 in ./venv/lib/python3.11/site-packages (from bert-score>=0.3.13->giskard[llm]>=2.0.0b) (2.1.0)
# Collecting transformers>=3.0.0 (from bert-score>=0.3.13->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for transformers>=3.0.0 from https://files.pythonhosted.org/packages/9a/06/e4ec2a321e57c03b7e9345d709d554a52c33760e5015fdff0919d9459af0/transformers-4.35.0-py3-none-any.whl.metadata
#   Using cached transformers-4.35.0-py3-none-any.whl.metadata (123 kB)
# Collecting tqdm>=4.31.1 (from bert-score>=0.3.13->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for tqdm>=4.31.1 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.11/site-packages (from bert-score>=0.3.13->giskard[llm]>=2.0.0b) (3.8.1)
# Collecting datasets>=2.0.0 (from evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for datasets>=2.0.0 from https://files.pythonhosted.org/packages/7c/55/b3432f43d6d7fee999bb23a547820d74c48ec540f5f7842e41aa5d8d5f3a/datasets-2.14.6-py3-none-any.whl.metadata
#   Downloading datasets-2.14.6-py3-none-any.whl.metadata (19 kB)
# Collecting dill (from evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for dill from https://files.pythonhosted.org/packages/f5/3a/74a29b11cf2cdfcd6ba89c0cecd70b37cd1ba7b77978ce611eb7a146a832/dill-0.3.7-py3-none-any.whl.metadata
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting multiprocess (from evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for multiprocess from https://files.pythonhosted.org/packages/e7/41/96ac938770ba6e7d5ae1d8c9cafebac54b413549042c6260f0d0a6ec6622/multiprocess-0.70.15-py311-none-any.whl.metadata
#   Downloading multiprocess-0.70.15-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in ./venv/lib/python3.11/site-packages (from evaluate>=0.4.1->giskard[llm]>=2.0.0b) (2023.10.0)
# Collecting huggingface-hub>=0.7.0 (from evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for huggingface-hub>=0.7.0 from https://files.pythonhosted.org/packages/64/8c/2766ce7e136eeb8b4d502e68eb1fe65342ee1aaf9129ec1c0838e5a4f0cb/huggingface_hub-0.19.0-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl.metadata (13 kB)
# Collecting responses<0.19 (from evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2>=3->giskard[llm]>=2.0.0b) (2.1.3)
# Collecting SQLAlchemy<3,>=1.4 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/c7/55/d1d2ad054fb7e9188681d56df40ed81c2c198314a805b180b0ec99019da1/SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for aiohttp<4.0.0,>=3.8.3 from https://files.pythonhosted.org/packages/8e/60/5d2a665713ce5f46d9fef626fee5dd4487cbcc3ee6f773706add1f872d92/aiohttp-3.8.6-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached aiohttp-3.8.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting anyio<4.0 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for anyio<4.0 from https://files.pythonhosted.org/packages/19/24/44299477fe7dcc9cb58d0a57d5a7588d6af2ff403fdd2d47a246c91a3246/anyio-3.7.1-py3-none-any.whl.metadata
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/21/1f/1cff009cff64420572b9f75b70e4a054095719179a172297dfdd65843162/dataclasses_json-0.6.1-py3-none-any.whl.metadata
#   Using cached dataclasses_json-0.6.1-py3-none-any.whl.metadata (24 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.1.0,>=0.0.38 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for langsmith<0.1.0,>=0.0.38 from https://files.pythonhosted.org/packages/d2/06/24590a71b497f0fc52f4001057c7c6149e008157b2332c5b0a4c5499f7d7/langsmith-0.0.62-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.62-py3-none-any.whl.metadata (10 kB)
# Collecting numexpr<3.0.0,>=2.8.4 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for numexpr<3.0.0,>=2.8.4 from https://files.pythonhosted.org/packages/0a/89/1b180ac1a8e0ee81f497ff491cfe917173b0fe42b3ad77e4afdbf3d5aecc/numexpr-2.8.7-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading numexpr-2.8.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for tenacity<9.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: six in ./venv/lib/python3.11/site-packages (from langdetect>=1.0.9->giskard[llm]>=2.0.0b) (1.16.0)
# Requirement already satisfied: urllib3 in ./venv/lib/python3.11/site-packages (from mixpanel>=4.4.0->giskard[llm]>=2.0.0b) (2.0.7)
# Collecting click<9,>=7.0 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for click<9,>=7.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle>=1.1.1 (from giskard[llm]>=2.0.0b)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for databricks-cli<1,>=0.8.7 from https://files.pythonhosted.org/packages/ae/a3/d56f8382c40899301f327d1c881278b09c9b8bc301c2c111633a0346d06e/databricks_cli-0.18.0-py2.py3-none-any.whl.metadata
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting entrypoints<1 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting gitpython<4,>=2.1.0 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for gitpython<4,>=2.1.0 from https://files.pythonhosted.org/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl.metadata
#   Using cached GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Collecting pytz<2024 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pytz<2024 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting importlib-metadata!=4.7.0,<7,>=3.7.0 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for importlib-metadata!=4.7.0,<7,>=3.7.0 from https://files.pythonhosted.org/packages/cc/37/db7ba97e676af155f5fcb1a35466f446eadc9104e25b83366e8088c9c926/importlib_metadata-6.8.0-py3-none-any.whl.metadata
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas>=1.3.4->giskard[llm]>=2.0.0b) (2.8.2)
# Collecting tzdata>=2022.1 (from pandas>=1.3.4->giskard[llm]>=2.0.0b)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic<3,>1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pydantic-core==2.10.1 from https://files.pythonhosted.org/packages/8d/ab/baf66342f1d18228ed3e54a05308b967c3de3692517f3237c570447e6256/pydantic_core-2.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached pydantic_core-2.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests>=2.19->giskard[llm]>=2.0.0b) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests>=2.19->giskard[llm]>=2.0.0b) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests>=2.19->giskard[llm]>=2.0.0b) (2023.7.22)
# Collecting joblib>=1.1.1 (from scikit-learn>=1.0->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=1.0->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting docopt<0.7.0,>=0.6.2 (from stomp-py>=8.1.0->giskard[llm]>=2.0.0b)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<=0.0.301->giskard[llm]>=2.0.0b) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Using cached multidict-6.0.4-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp<4.0.0,>=3.8.3->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for async-timeout<5.0,>=4.0.0a3 from https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl.metadata
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Using cached yarl-1.9.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/9d/8b/8ab8143541b2c5fff4189fad7853e61d30e4ec4749ebf91e1d598c4e7c57/frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.11/site-packages (from anyio<4.0->langchain<=0.0.301->giskard[llm]>=2.0.0b) (1.3.0)
# Collecting pyjwt>=1.7.0 (from databricks-cli<1,>=0.8.7->mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pyjwt>=1.7.0 from https://files.pythonhosted.org/packages/2b/4f/e04a8067c7c96c364cef7ef73906504e2f40d690811c021e1a1901473a19/PyJWT-2.8.0-py3-none-any.whl.metadata
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting oauthlib>=3.1.0 (from databricks-cli<1,>=0.8.7->mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting tabulate>=0.7.7 (from databricks-cli<1,>=0.8.7->mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/ed/3c/cebfdcad015240014ff08b883d1c0c427f2ba45ae8c6572851b6ef136cad/marshmallow-3.20.1-py3-none-any.whl.metadata
#   Using cached marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyarrow>=8.0.0 (from datasets>=2.0.0->evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pyarrow>=8.0.0 from https://files.pythonhosted.org/packages/58/4e/bd9bf0aaead74ba46996cf11a608894e1867e8e5f850fd7679018a117c60/pyarrow-14.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pyarrow-14.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]>=2.0.0b) (3.13.1)
# Collecting zipp>=0.5 (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl.metadata
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain<=0.0.301->giskard[llm]>=2.0.0b) (2.4)
# Collecting pytest-subtests<0.12.0,>=0.11.0 (from langsmith<0.1.0,>=0.0.38->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pytest-subtests<0.12.0,>=0.11.0 from https://files.pythonhosted.org/packages/8a/98/50ac2d1344b0c43b81f886171e5ecf51a27fd02b32f787862f76fd7779dc/pytest_subtests-0.11.0-py3-none-any.whl.metadata
#   Downloading pytest_subtests-0.11.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: sympy in ./venv/lib/python3.11/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (1.12)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (3.2.1)
# Collecting regex!=2019.12.17 (from transformers>=3.0.0->bert-score>=0.3.13->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/4d/d3/38b09813a32618acd437906c4d0194119e27139dbcd7486e69d58e375a27/regex-2023.10.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached regex-2023.10.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=3.0.0->bert-score>=0.3.13->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for tokenizers<0.15,>=0.14 from https://files.pythonhosted.org/packages/7e/8e/9c0f7799da9a690ec29a7a7b6c0744d3f735e40951d2f62c8202faf3df6a/tokenizers-0.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached tokenizers-0.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.3.1 (from transformers>=3.0.0->bert-score>=0.3.13->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for safetensors>=0.3.1 from https://files.pythonhosted.org/packages/91/4f/bded5d0435a72f1bd39f5aaa81077d84fa39526a7c055cc8b8aa44fce681/safetensors-0.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached safetensors-0.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.11/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (1.4.5)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.11/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (3.1.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow-skinny>=2->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting pytest>=7.0 (from pytest-subtests<0.12.0,>=0.11.0->langsmith<0.1.0,>=0.0.38->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pytest>=7.0 from https://files.pythonhosted.org/packages/f3/8c/f16efd81ca8e293b2cc78f111190a79ee539d0d5d36ccd49975cb3beac60/pytest-7.4.3-py3-none-any.whl.metadata
#   Downloading pytest-7.4.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting huggingface-hub>=0.7.0 (from evaluate>=0.4.1->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for huggingface-hub>=0.7.0 from https://files.pythonhosted.org/packages/aa/f3/3fc97336a0e90516901befd4f500f08d691034d387406fdbde85bea827cc/huggingface_hub-0.17.3-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: mpmath>=0.19 in ./venv/lib/python3.11/site-packages (from sympy->torch>=1.0.0->bert-score>=0.3.13->giskard[llm]>=2.0.0b) (1.3.0)
# Collecting iniconfig (from pytest>=7.0->pytest-subtests<0.12.0,>=0.11.0->langsmith<0.1.0,>=0.0.38->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest>=7.0->pytest-subtests<0.12.0,>=0.11.0->langsmith<0.1.0,>=0.0.38->langchain<=0.0.301->giskard[llm]>=2.0.0b)
#   Obtaining dependency information for pluggy<2.0,>=0.12 from https://files.pythonhosted.org/packages/05/b8/42ed91898d4784546c5f06c60506400548db3f7a4b3fb441cba4e5c17952/pluggy-1.3.0-py3-none-any.whl.metadata
#   Using cached pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.9 MB/s eta 0:00:00
# Downloading langchain-0.0.301-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Downloading mlflow_skinny-2.8.0-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 750.6 kB/s eta 0:00:0000:0100:01
# Using cached openai-0.28.1-py3-none-any.whl (76 kB)
# Using cached pandas-2.1.2-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# Using cached pydantic_core-2.10.1-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
# Using cached scikit_learn-1.3.2-cp311-cp311-macosx_12_0_arm64.whl (9.4 MB)
# Using cached scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl (29.7 MB)
# Downloading xxhash-3.4.1-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl (703 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 703.4/703.4 kB 930.7 kB/s eta 0:00:0000:0100:01
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 951.4 kB/s eta 0:00:00 0:00:01
# Downloading giskard-2.0.2-py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.1/505.1 kB 990.8 kB/s eta 0:00:000:0100:01
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 1.1 MB/s eta 0:00:00 0:00:01
# Using cached aiohttp-3.8.6-cp311-cp311-macosx_11_0_arm64.whl (343 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Using cached dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 605.1 kB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 388.8 kB/s eta 0:00:00a 0:00:01
# Using cached GitPython-3.1.40-py3-none-any.whl (190 kB)
# Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.0.62-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 543.7 kB/s eta 0:00:00a 0:00:01
# Downloading numexpr-2.8.7-cp311-cp311-macosx_11_0_arm64.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 652.0 kB/s eta 0:00:00a 0:00:01
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached transformers-4.35.0-py3-none-any.whl (7.9 MB)
# Downloading multiprocess-0.70.15-py311-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 548.5 kB/s eta 0:00:00a 0:00:01
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl (46 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Downloading pyarrow-14.0.1-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 905.9 kB/s eta 0:00:0000:0100:01
# Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Downloading pytest_subtests-0.11.0-py3-none-any.whl (6.7 kB)
# Using cached regex-2023.10.3-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
# Using cached safetensors-0.4.0-cp311-cp311-macosx_11_0_arm64.whl (425 kB)
# Using cached tokenizers-0.14.1-cp311-cp311-macosx_11_0_arm64.whl (2.5 MB)
# Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading pytest-7.4.3-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.1/325.1 kB 920.7 kB/s eta 0:00:00 0:00:01
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached pluggy-1.3.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=8b1e322972114c38033f20d61d60fc0e6db7a62a351a0c7660b7a32b935ea586
#   Stored in directory: /Users/sohom/Library/Caches/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: pytz, docopt, zstandard, zipp, xxhash, tzdata, tqdm, threadpoolctl, tenacity, tabulate, stomp-py, sqlparse, SQLAlchemy, smmap, scipy, safetensors, regex, pyjwt, pydantic-core, pyarrow, protobuf, pluggy, oauthlib, numexpr, mypy-extensions, multidict, marshmallow, markdown, langdetect, jsonpatch, joblib, iniconfig, frozenlist, entrypoints, dill, colorama, cloudpickle, click, chardet, async-timeout, anyio, annotated-types, yarl, typing-inspect, scikit-learn, responses, requests-toolbelt, pytest, pydantic, pandas, multiprocess, mixpanel, importlib-metadata, huggingface-hub, gitdb, databricks-cli, aiosignal, tokenizers, pytest-subtests, gitpython, dataclasses-json, aiohttp, transformers, openai, mlflow-skinny, langsmith, langchain, giskard, datasets, bert-score, evaluate
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.0.0
#     Uninstalling anyio-4.0.0:
#       Successfully uninstalled anyio-4.0.0
# Successfully installed SQLAlchemy-2.0.23 aiohttp-3.8.6 aiosignal-1.3.1 annotated-types-0.6.0 anyio-3.7.1 async-timeout-4.0.3 bert-score-0.3.13 chardet-5.2.0 click-8.1.7 cloudpickle-2.2.1 colorama-0.4.6 databricks-cli-0.18.0 dataclasses-json-0.6.1 datasets-2.14.6 dill-0.3.7 docopt-0.6.2 entrypoints-0.4 evaluate-0.4.1 frozenlist-1.4.0 giskard-2.0.2 gitdb-4.0.11 gitpython-3.1.40 huggingface-hub-0.17.3 importlib-metadata-6.8.0 iniconfig-2.0.0 joblib-1.3.2 jsonpatch-1.33 langchain-0.0.301 langdetect-1.0.9 langsmith-0.0.62 markdown-3.5.1 marshmallow-3.20.1 mixpanel-4.10.0 mlflow-skinny-2.8.0 multidict-6.0.4 multiprocess-0.70.15 mypy-extensions-1.0.0 numexpr-2.8.7 oauthlib-3.2.2 openai-0.28.1 pandas-2.1.2 pluggy-1.3.0 protobuf-3.20.3 pyarrow-14.0.1 pydantic-2.4.2 pydantic-core-2.10.1 pyjwt-2.8.0 pytest-7.4.3 pytest-subtests-0.11.0 pytz-2023.3.post1 regex-2023.10.3 requests-toolbelt-1.0.0 responses-0.18.0 safetensors-0.4.0 scikit-learn-1.3.2 scipy-1.11.3 smmap-5.0.1 sqlparse-0.4.4 stomp-py-8.1.0 tabulate-0.9.0 tenacity-8.2.3 threadpoolctl-3.2.0 tokenizers-0.14.1 tqdm-4.66.1 transformers-4.35.0 typing-inspect-0.9.0 tzdata-2023.3 xxhash-3.4.1 yarl-1.9.2 zipp-3.17.0 zstandard-0.22.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain pypdf faiss-cpu openai==0.27.0 tiktoken
# Out:
# Requirement already satisfied: langchain in ./venv/lib/python3.11/site-packages (0.0.301)
# Collecting pypdf
#   Obtaining dependency information for pypdf from https://files.pythonhosted.org/packages/74/a9/5ccde1312650dd03e65350224fea85d9a430c182a01f056599cbb76f7390/pypdf-3.17.0-py3-none-any.whl.metadata
#   Using cached pypdf-3.17.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.7.4-cp311-cp311-macosx_11_0_arm64.whl (2.7 MB)
# Collecting openai==0.27.0
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting tiktoken
#   Obtaining dependency information for tiktoken from https://files.pythonhosted.org/packages/fb/2a/3d02ef030f387c373acbeca6d5a2307405a1da735285ec12a9ed0b6302ea/tiktoken-0.5.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached tiktoken-0.5.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: requests>=2.20 in ./venv/lib/python3.11/site-packages (from openai==0.27.0) (2.31.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.11/site-packages (from openai==0.27.0) (4.66.1)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.11/site-packages (from openai==0.27.0) (3.8.6)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv/lib/python3.11/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: anyio<4.0 in ./venv/lib/python3.11/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./venv/lib/python3.11/site-packages (from langchain) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.11/site-packages (from langchain) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.38 in ./venv/lib/python3.11/site-packages (from langchain) (0.0.62)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in ./venv/lib/python3.11/site-packages (from langchain) (2.8.7)
# Requirement already satisfied: numpy<2,>=1 in ./venv/lib/python3.11/site-packages (from langchain) (1.26.1)
# Requirement already satisfied: pydantic<3,>=1 in ./venv/lib/python3.11/site-packages (from langchain) (2.4.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./venv/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.11/site-packages (from tiktoken) (2023.10.3)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.11/site-packages (from aiohttp->openai==0.27.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.11/site-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.11/site-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: pytest-subtests<0.12.0,>=0.11.0 in ./venv/lib/python3.11/site-packages (from langsmith<0.1.0,>=0.0.38->langchain) (0.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./venv/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in ./venv/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./venv/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.11/site-packages (from requests>=2.20->openai==0.27.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests>=2.20->openai==0.27.0) (2023.7.22)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Requirement already satisfied: pytest>=7.0 in ./venv/lib/python3.11/site-packages (from pytest-subtests<0.12.0,>=0.11.0->langsmith<0.1.0,>=0.0.38->langchain) (7.4.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: iniconfig in ./venv/lib/python3.11/site-packages (from pytest>=7.0->pytest-subtests<0.12.0,>=0.11.0->langsmith<0.1.0,>=0.0.38->langchain) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in ./venv/lib/python3.11/site-packages (from pytest>=7.0->pytest-subtests<0.12.0,>=0.11.0->langsmith<0.1.0,>=0.0.38->langchain) (1.3.0)
# Using cached pypdf-3.17.0-py3-none-any.whl (277 kB)
# Using cached tiktoken-0.5.1-cp311-cp311-macosx_11_0_arm64.whl (924 kB)
# Installing collected packages: faiss-cpu, pypdf, tiktoken, openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.1
#     Uninstalling openai-0.28.1:
#       Successfully uninstalled openai-0.28.1
# Successfully installed faiss-cpu-1.7.4 openai-0.27.0 pypdf-3.17.0 tiktoken-0.5.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pathlib import Path
import openai
import pandas as pd
from langchain.llms import openai
from langchain import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.chains.base import Chain
from langchain.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.embeddings import OpenAIEmbeddings
from langchain.document_loaders import PyPDFLoader
from langchain.chains import RetrievalQA, load_chain
from langchain.text_splitter import RecursiveCharacterTextSplitter

from giskard import Dataset, Model, scan, GiskardClient

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
pd.set_option('display.max_colwidth', None)

# %%
URL = "https://www.ipcc.ch/report/ar6/syr/downloads/report/IPCC_AR6_SYR_LongerReport.pdf"

# %%
LLM_NAME = "gpt-3.5-turbo"

# %%
TEXT_COLUMN_QUERY = "query"

# %%
PROMPT_TEMPLATE = """You are the climate assistant, a helpful assistant made by Giskard.
Your task is to answer common questions on climate change.
You will be given a question and relevant excerpts from the IPCC Climate Change Synthesis Report (2023).
Please provide short and clear answers based on the provided context. Be polite and Helpful,

Context:
{context}

Question:
{question}

Your answer:
"""

# %%
def get_context_storage() -> FAISS:
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100, add_start_index=True)
    docs = PyPDFLoader(URL).load_and_split(text_splitter)
    db = FAISS.from_documents(docs, OpenAIEmbeddings())
    return db

# %%
llm = OpenAI(temperature=0.1, model_name=LLM_NAME)
# Out:
# /Users/sohom/giskard/venv/lib/python3.11/site-packages/langchain/llms/openai.py:202: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /Users/sohom/giskard/venv/lib/python3.11/site-packages/langchain/llms/openai.py:790: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(

# %%
prompt = PromptTemplate(template=PROMPT_TEMPLATE, input_variables=["context", "question"])

# %%
def get_context_storage() -> FAISS:
    """Initialize a vector storage of embedded IPCC report chunks (context)."""
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100, add_start_index=True)
    docs = PyPDFLoader(IPCC_REPORT_URL).load_and_split(text_splitter)
    db = FAISS.from_documents(docs, OpenAIEmbeddings())
    return db


# Create the chain.
llm = OpenAI(temperature=0)
prompt = PromptTemplate(template=PROMPT_TEMPLATE, input_variables=["question", "context"])
climate_qa_chain = RetrievalQA.from_llm(llm=llm, retriever=get_context_storage().as_retriever(), prompt=prompt)

# Test the chain.
climate_qa_chain("Is sea level rise avoidable? When will it stop?")

# %%
# Define a custom Giskard model wrapper for the serialization.
class FAISSRAGModel(Model):
    def model_predict(self, df: pd.DataFrame) -> pd.DataFrame:
        return df[TEXT_COLUMN_NAME].apply(lambda x: self.model.run({"query": x}))

    def save_model(self, path: str):
        out_dest = Path(path)
        # Save the chain object
        self.model.save(out_dest.joinpath("model.json"))

        # Save the FAISS-based retriever
        db = self.model.retriever.vectorstore
        db.save_local(out_dest.joinpath("faiss"))

    @classmethod
    def load_model(cls, path: str) -> Chain:
        src = Path(path)

        # Load the FAISS-based retriever
        db = FAISS.load_local(src.joinpath("faiss"), OpenAIEmbeddings())

        # Load the chain, passing the retriever
        chain = load_chain(src.joinpath("model.json"), retriever=db.as_retriever())
        return chain


# Wrap the QA chain
giskard_model = FAISSRAGModel(
    model=climate_qa_chain,  # A prediction function that encapsulates all the data pre-processing steps and that could be executed with the dataset used by the scan.
    model_type="text_generation",  # Either regression, classification or text_generation.
    name="Climate Change Question Answering",  # Optional.
    description="This model answers any question about climate change based on IPCC reports",  # Is used to generate prompts during the scan.
    feature_names=[TEXT_COLUMN_NAME]  # Default: all columns of your dataset.
)

# Optional: Wrap a dataframe of sample input prompts to validate the model wrapping and to narrow specific tests' queries.
giskard_dataset = Dataset(pd.DataFrame({
    TEXT_COLUMN_NAME: [
        "According to the IPCC report, what are key risks in the Europe?",
        "Is sea level rise avoidable? When will it stop?"
    ]
}))

# %%
# Validate the wrapped model and dataset.
print(giskard_model.predict(giskard_dataset).prediction)

# %%
results = scan(giskard_model, giskard_dataset, only="hallucination")

# %%
display(results)

# %%
test_suite = results.generate_test_suite("Test suite generated by scan")
test_suite.run()
